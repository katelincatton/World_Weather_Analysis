# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd

from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = list(zip(lats,lngs))

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 783

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lata
# Processing Record 2 of Set 1 | kirakira
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | kilindoni
# Processing Record 5 of Set 1 | turukhansk
# Processing Record 6 of Set 1 | college
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | bahia honda
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | jesup
# Processing Record 14 of Set 1 | valparaiso
# Processing Record 15 of Set 1 | kollam
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | coihaique
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | chifeng
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | vila franca do campo
# Processing Record 25 of Set 1 | alekseyevka
# Processing Record 26 of Set 1 | bereda
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | port lincoln
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | gouyave
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | arcata
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | akureyri
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | hailar
# Processing Record 1 of Set 2 | venezuela
# Processing Record 2 of Set 2 | uvinza
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | luderitz
# Processing Record 5 of Set 2 | tamiahua
# Processing Record 6 of Set 2 | kimbe
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | codrington
# Processing Record 9 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 2 | cacoal
# Processing Record 13 of Set 2 | kiunga
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | gelemso
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | bud
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | chabahar
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | pemba
# Processing Record 26 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 2 | czersk
# Processing Record 28 of Set 2 | sao sebastiao
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | tura
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | brits
# Processing Record 35 of Set 2 | changji
# Processing Record 36 of Set 2 | lagoa
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | sisimiut
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | abu samrah
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | golyshmanovo
# Processing Record 45 of Set 2 | gorgan
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | sorland
# Processing Record 50 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 3 | otautau
# Processing Record 2 of Set 3 | mahibadhoo
# Processing Record 3 of Set 3 | scarborough
# Processing Record 4 of Set 3 | copiapo
# Processing Record 5 of Set 3 | mirnyy
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | sawtell
# Processing Record 8 of Set 3 | deniliquin
# Processing Record 9 of Set 3 | sao felix do xingu
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | vryburg
# Processing Record 14 of Set 3 | sawakin
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | rassvet
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | ende
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | comodoro rivadavia
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | naze
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 3 | praia
# Processing Record 26 of Set 3 | ngunguru
# Processing Record 27 of Set 3 | betsiamites
# Processing Record 28 of Set 3 | kungurtug
# Processing Record 29 of Set 3 | hasaki
# Processing Record 30 of Set 3 | grindavik
# Processing Record 31 of Set 3 | pacific grove
# Processing Record 32 of Set 3 | sao jose da coroa grande
# Processing Record 33 of Set 3 | galesong
# Processing Record 34 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 3 | pabrade
# Processing Record 36 of Set 3 | lazarev
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | port hardy
# Processing Record 39 of Set 3 | ust-omchug
# Processing Record 40 of Set 3 | vysotsk
# Processing Record 41 of Set 3 | atuona
# Processing Record 42 of Set 3 | pingchen
# City not found. Skipping...
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 3 | komyshnya
# Processing Record 46 of Set 3 | shubarkuduk
# Processing Record 47 of Set 3 | rio grande
# Processing Record 48 of Set 3 | baltiysk
# Processing Record 49 of Set 3 | bairiki
# Processing Record 50 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | entre rios
# Processing Record 2 of Set 4 | progreso
# Processing Record 3 of Set 4 | fare
# Processing Record 4 of Set 4 | galle
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | belmonte
# Processing Record 7 of Set 4 | maldonado
# Processing Record 8 of Set 4 | ayr
# Processing Record 9 of Set 4 | svetlogorsk
# Processing Record 10 of Set 4 | isilkul
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | chulman
# Processing Record 13 of Set 4 | srednekolymsk
# Processing Record 14 of Set 4 | geraldton
# Processing Record 15 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 4 | marsh harbour
# Processing Record 17 of Set 4 | tabou
# Processing Record 18 of Set 4 | honningsvag
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | yarensk
# Processing Record 22 of Set 4 | caravelas
# Processing Record 23 of Set 4 | lieksa
# Processing Record 24 of Set 4 | port blair
# Processing Record 25 of Set 4 | kununurra
# Processing Record 26 of Set 4 | los llanos de aridane
# Processing Record 27 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 4 | angoche
# Processing Record 29 of Set 4 | ola
# Processing Record 30 of Set 4 | the valley
# Processing Record 31 of Set 4 | lasa
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | baykit
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | puerto escondido
# Processing Record 36 of Set 4 | herford
# Processing Record 37 of Set 4 | alofi
# Processing Record 38 of Set 4 | ushtobe
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | gornopravdinsk
# Processing Record 41 of Set 4 | songea
# Processing Record 42 of Set 4 | butembo
# Processing Record 43 of Set 4 | carbonear
# Processing Record 44 of Set 4 | yanam
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | berbera
# Processing Record 47 of Set 4 | clyde river
# Processing Record 48 of Set 4 | guilin
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | nanortalik
# Processing Record 2 of Set 5 | bela vista
# Processing Record 3 of Set 5 | urubicha
# Processing Record 4 of Set 5 | rantepao
# Processing Record 5 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 5 | nikolskoye
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | san quintin
# Processing Record 9 of Set 5 | kudahuvadhoo
# Processing Record 10 of Set 5 | antofagasta
# Processing Record 11 of Set 5 | tianpeng
# Processing Record 12 of Set 5 | riacho de santana
# Processing Record 13 of Set 5 | pringsewu
# Processing Record 14 of Set 5 | odesskoye
# Processing Record 15 of Set 5 | pinega
# Processing Record 16 of Set 5 | fukuyama
# Processing Record 17 of Set 5 | high level
# Processing Record 18 of Set 5 | mantua
# Processing Record 19 of Set 5 | ambilobe
# Processing Record 20 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 5 | rosarito
# Processing Record 22 of Set 5 | klaksvik
# Processing Record 23 of Set 5 | hofn
# Processing Record 24 of Set 5 | sibolga
# Processing Record 25 of Set 5 | teya
# Processing Record 26 of Set 5 | atar
# Processing Record 27 of Set 5 | gat
# Processing Record 28 of Set 5 | kruisfontein
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | bahia blanca
# Processing Record 31 of Set 5 | ayan
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | mogadishu
# Processing Record 34 of Set 5 | woodward
# Processing Record 35 of Set 5 | hilo
# Processing Record 36 of Set 5 | berlevag
# Processing Record 37 of Set 5 | polkowice
# Processing Record 38 of Set 5 | palana
# Processing Record 39 of Set 5 | witu
# Processing Record 40 of Set 5 | nago
# Processing Record 41 of Set 5 | belen
# Processing Record 42 of Set 5 | dwarka
# Processing Record 43 of Set 5 | canita
# Processing Record 44 of Set 5 | umm lajj
# Processing Record 45 of Set 5 | boden
# Processing Record 46 of Set 5 | mackenzie
# Processing Record 47 of Set 5 | chardara
# Processing Record 48 of Set 5 | hualmay
# Processing Record 49 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 6 | port hedland
# Processing Record 2 of Set 6 | fort nelson
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | beringovskiy
# Processing Record 5 of Set 6 | jaru
# Processing Record 6 of Set 6 | tamandare
# Processing Record 7 of Set 6 | mana
# Processing Record 8 of Set 6 | akdagmadeni
# Processing Record 9 of Set 6 | harlingen
# Processing Record 10 of Set 6 | poum
# Processing Record 11 of Set 6 | gao
# Processing Record 12 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | tongren
# Processing Record 14 of Set 6 | kavieng
# Processing Record 15 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 6 | egvekinot
# Processing Record 17 of Set 6 | omboue
# Processing Record 18 of Set 6 | tilichiki
# Processing Record 19 of Set 6 | aykhal
# Processing Record 20 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 6 | mount pleasant
# Processing Record 22 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 6 | charters towers
# Processing Record 24 of Set 6 | qesarya
# Processing Record 25 of Set 6 | kushmurun
# Processing Record 26 of Set 6 | saint-francois
# Processing Record 27 of Set 6 | salalah
# Processing Record 28 of Set 6 | arona
# Processing Record 29 of Set 6 | usogorsk
# Processing Record 30 of Set 6 | flic en flac
# Processing Record 31 of Set 6 | tres arroyos
# Processing Record 32 of Set 6 | khandyga
# Processing Record 33 of Set 6 | beipiao
# Processing Record 34 of Set 6 | rafaela
# Processing Record 35 of Set 6 | nouadhibou
# Processing Record 36 of Set 6 | kiblawan
# Processing Record 37 of Set 6 | beisfjord
# Processing Record 38 of Set 6 | hamilton
# Processing Record 39 of Set 6 | sistranda
# Processing Record 40 of Set 6 | eufaula
# Processing Record 41 of Set 6 | aklavik
# Processing Record 42 of Set 6 | avera
# Processing Record 43 of Set 6 | iqaluit
# Processing Record 44 of Set 6 | dzaoudzi
# Processing Record 45 of Set 6 | atambua
# Processing Record 46 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 6 | blagoyevo
# Processing Record 48 of Set 6 | sinjar
# Processing Record 49 of Set 6 | qaqortoq
# Processing Record 50 of Set 6 | shambu
# Processing Record 1 of Set 7 | belomorsk
# Processing Record 2 of Set 7 | georgetown
# Processing Record 3 of Set 7 | shaoyang
# Processing Record 4 of Set 7 | porto novo
# Processing Record 5 of Set 7 | predivinsk
# Processing Record 6 of Set 7 | auki
# Processing Record 7 of Set 7 | hearst
# Processing Record 8 of Set 7 | katobu
# Processing Record 9 of Set 7 | nuevitas
# Processing Record 10 of Set 7 | faranah
# Processing Record 11 of Set 7 | quatre cocos
# Processing Record 12 of Set 7 | tautira
# Processing Record 13 of Set 7 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 14 of Set 7 | kokopo
# Processing Record 15 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 16 of Set 7 | marrakesh
# Processing Record 17 of Set 7 | dudinka
# Processing Record 18 of Set 7 | durban
# Processing Record 19 of Set 7 | marsa matruh
# Processing Record 20 of Set 7 | xuddur
# Processing Record 21 of Set 7 | varaklani
# City not found. Skipping...
# Processing Record 22 of Set 7 | airai
# Processing Record 23 of Set 7 | soyo
# Processing Record 24 of Set 7 | tihemetsa
# Processing Record 25 of Set 7 | hambantota
# Processing Record 26 of Set 7 | burica
# City not found. Skipping...
# Processing Record 27 of Set 7 | nuuk
# Processing Record 28 of Set 7 | channel-port aux basques
# Processing Record 29 of Set 7 | gamba
# Processing Record 30 of Set 7 | sidi ali
# Processing Record 31 of Set 7 | kutum
# Processing Record 32 of Set 7 | kinablangan
# Processing Record 33 of Set 7 | mahanje
# Processing Record 34 of Set 7 | saint-paul
# Processing Record 35 of Set 7 | katsuura
# Processing Record 36 of Set 7 | mackay
# Processing Record 37 of Set 7 | khorixas
# Processing Record 38 of Set 7 | antrim
# Processing Record 39 of Set 7 | bengkulu
# Processing Record 40 of Set 7 | pimentel
# Processing Record 41 of Set 7 | ahipara
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | alta floresta
# Processing Record 44 of Set 7 | cockburn town
# Processing Record 45 of Set 7 | hervey bay
# Processing Record 46 of Set 7 | neiafu
# Processing Record 47 of Set 7 | santa isabel
# Processing Record 48 of Set 7 | bartica
# Processing Record 49 of Set 7 | zheleznodorozhnyy
# Processing Record 50 of Set 7 | sao joao da barra
# Processing Record 1 of Set 8 | kochi
# Processing Record 2 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 8 | canutama
# Processing Record 4 of Set 8 | saskylakh
# Processing Record 5 of Set 8 | riaba
# City not found. Skipping...
# Processing Record 6 of Set 8 | lafia
# Processing Record 7 of Set 8 | morondava
# Processing Record 8 of Set 8 | esperance
# Processing Record 9 of Set 8 | babstovo
# Processing Record 10 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 8 | mabaruma
# Processing Record 12 of Set 8 | lehututu
# Processing Record 13 of Set 8 | camapua
# Processing Record 14 of Set 8 | morehead
# Processing Record 15 of Set 8 | maraa
# Processing Record 16 of Set 8 | togur
# Processing Record 17 of Set 8 | beyneu
# Processing Record 18 of Set 8 | gigmoto
# Processing Record 19 of Set 8 | buchanan
# Processing Record 20 of Set 8 | barra patuca
# Processing Record 21 of Set 8 | salaverry
# Processing Record 22 of Set 8 | samfya
# Processing Record 23 of Set 8 | inta
# Processing Record 24 of Set 8 | saint-gabriel
# Processing Record 25 of Set 8 | kyra
# Processing Record 26 of Set 8 | lugovskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | biak
# Processing Record 28 of Set 8 | pokosnoye
# Processing Record 29 of Set 8 | utiel
# Processing Record 30 of Set 8 | rrogozhine
# Processing Record 31 of Set 8 | pandan
# Processing Record 32 of Set 8 | olafsvik
# Processing Record 33 of Set 8 | cabedelo
# Processing Record 34 of Set 8 | quilmana
# Processing Record 35 of Set 8 | craig
# Processing Record 36 of Set 8 | half moon bay
# Processing Record 37 of Set 8 | eresos
# Processing Record 38 of Set 8 | saryozek
# Processing Record 39 of Set 8 | gopalganj
# Processing Record 40 of Set 8 | santa rosa
# Processing Record 41 of Set 8 | pilao arcado
# City not found. Skipping...
# Processing Record 42 of Set 8 | bethel
# Processing Record 43 of Set 8 | rawson
# Processing Record 44 of Set 8 | mindelo
# Processing Record 45 of Set 8 | santa flavia
# Processing Record 46 of Set 8 | sholapur
# Processing Record 47 of Set 8 | svobodnyy
# Processing Record 48 of Set 8 | warri
# Processing Record 49 of Set 8 | qixia
# Processing Record 50 of Set 8 | tiksi
# Processing Record 1 of Set 9 | liuzhou
# Processing Record 2 of Set 9 | miri
# Processing Record 3 of Set 9 | mankato
# Processing Record 4 of Set 9 | novikovo
# Processing Record 5 of Set 9 | adrar
# Processing Record 6 of Set 9 | mount isa
# Processing Record 7 of Set 9 | vanimo
# Processing Record 8 of Set 9 | rocha
# Processing Record 9 of Set 9 | poputnaya
# Processing Record 10 of Set 9 | okato
# Processing Record 11 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 12 of Set 9 | tawang
# Processing Record 13 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 9 | vila velha
# Processing Record 15 of Set 9 | marawi
# Processing Record 16 of Set 9 | sioux lookout
# Processing Record 17 of Set 9 | hami
# Processing Record 18 of Set 9 | mafeteng
# Processing Record 19 of Set 9 | zharkent
# Processing Record 20 of Set 9 | batagay
# Processing Record 21 of Set 9 | kamenka
# Processing Record 22 of Set 9 | whitehorse
# Processing Record 23 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 24 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 25 of Set 9 | belyy yar
# Processing Record 26 of Set 9 | namatanai
# Processing Record 27 of Set 9 | shimoda
# Processing Record 28 of Set 9 | fortuna
# Processing Record 29 of Set 9 | ahuimanu
# Processing Record 30 of Set 9 | nianzishan
# Processing Record 31 of Set 9 | mattru
# Processing Record 32 of Set 9 | vikhorevka
# Processing Record 33 of Set 9 | mandera
# Processing Record 34 of Set 9 | ust-kuyga
# Processing Record 35 of Set 9 | ugoofaaru
# Processing Record 36 of Set 9 | fatehabad
# Processing Record 37 of Set 9 | parambu
# Processing Record 38 of Set 9 | cajati
# Processing Record 39 of Set 9 | dingle
# Processing Record 40 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 9 | yeppoon
# Processing Record 42 of Set 9 | andilamena
# Processing Record 43 of Set 9 | bubaque
# Processing Record 44 of Set 9 | preobrazheniye
# Processing Record 45 of Set 9 | mahon
# Processing Record 46 of Set 9 | saint-denis
# Processing Record 47 of Set 9 | sumbe
# Processing Record 48 of Set 9 | berezovyy
# Processing Record 49 of Set 9 | nerja
# Processing Record 50 of Set 9 | sobolevo
# Processing Record 1 of Set 10 | lillooet
# Processing Record 2 of Set 10 | touros
# Processing Record 3 of Set 10 | paamiut
# Processing Record 4 of Set 10 | ati
# Processing Record 5 of Set 10 | mandalgovi
# Processing Record 6 of Set 10 | hovd
# Processing Record 7 of Set 10 | kiruna
# Processing Record 8 of Set 10 | anadyr
# Processing Record 9 of Set 10 | arlit
# Processing Record 10 of Set 10 | sao geraldo do araguaia
# Processing Record 11 of Set 10 | ghanzi
# Processing Record 12 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 10 | skjervoy
# Processing Record 14 of Set 10 | fairmont
# Processing Record 15 of Set 10 | ormara
# Processing Record 16 of Set 10 | pangnirtung
# Processing Record 17 of Set 10 | pascagoula
# Processing Record 18 of Set 10 | chara
# Processing Record 19 of Set 10 | salisbury
# Processing Record 20 of Set 10 | voznesenskoye
# Processing Record 21 of Set 10 | palizada
# Processing Record 22 of Set 10 | moron
# Processing Record 23 of Set 10 | catamarca
# Processing Record 24 of Set 10 | sao filipe
# Processing Record 25 of Set 10 | vuktyl
# Processing Record 26 of Set 10 | coldwater
# Processing Record 27 of Set 10 | tromso
# Processing Record 28 of Set 10 | devils lake
# Processing Record 29 of Set 10 | tahta
# Processing Record 30 of Set 10 | portobelo
# Processing Record 31 of Set 10 | kidal
# Processing Record 32 of Set 10 | bosaso
# Processing Record 33 of Set 10 | wajima
# Processing Record 34 of Set 10 | dukat
# Processing Record 35 of Set 10 | portoferraio
# Processing Record 36 of Set 10 | baglan
# Processing Record 37 of Set 10 | jiangyan
# Processing Record 38 of Set 10 | ostrovnoy
# Processing Record 39 of Set 10 | cairns
# Processing Record 40 of Set 10 | erenhot
# Processing Record 41 of Set 10 | lubyany
# Processing Record 42 of Set 10 | nyurba
# Processing Record 43 of Set 10 | faya
# Processing Record 44 of Set 10 | tanhacu
# Processing Record 45 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 46 of Set 10 | kuryk
# Processing Record 47 of Set 10 | ulladulla
# Processing Record 48 of Set 10 | ipixuna
# Processing Record 49 of Set 10 | gezing
# Processing Record 50 of Set 10 | torbay
# Processing Record 1 of Set 11 | vanavara
# Processing Record 2 of Set 11 | imeni poliny osipenko
# Processing Record 3 of Set 11 | nouakchott
# Processing Record 4 of Set 11 | izhma
# Processing Record 5 of Set 11 | khalilabad
# Processing Record 6 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 7 of Set 11 | tombouctou
# Processing Record 8 of Set 11 | dakoro
# Processing Record 9 of Set 11 | lushunkou
# City not found. Skipping...
# Processing Record 10 of Set 11 | lavrentiya
# Processing Record 11 of Set 11 | gardner
# Processing Record 12 of Set 11 | deputatskiy
# Processing Record 13 of Set 11 | alvorada
# Processing Record 14 of Set 11 | pisco
# Processing Record 15 of Set 11 | soldotna
# Processing Record 16 of Set 11 | dubai
# Processing Record 17 of Set 11 | leningradskiy
# Processing Record 18 of Set 11 | okhotsk
# Processing Record 19 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 20 of Set 11 | labuhan
# Processing Record 21 of Set 11 | palatka
# Processing Record 22 of Set 11 | llanes
# Processing Record 23 of Set 11 | te anau
# Processing Record 24 of Set 11 | udachnyy
# Processing Record 25 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 11 | ukiah
# Processing Record 27 of Set 11 | ogbomosho
# Processing Record 28 of Set 11 | ruidoso
# Processing Record 29 of Set 11 | edremit
# Processing Record 30 of Set 11 | vitim
# Processing Record 31 of Set 11 | senmonorom
# City not found. Skipping...
# Processing Record 32 of Set 11 | mehamn
# Processing Record 33 of Set 11 | north platte
# Processing Record 34 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 11 | pedernales
# Processing Record 36 of Set 11 | kapuskasing
# Processing Record 37 of Set 11 | byron bay
# Processing Record 38 of Set 11 | port macquarie
# Processing Record 39 of Set 11 | casablanca
# Processing Record 40 of Set 11 | clyde
# Processing Record 41 of Set 11 | seljord
# Processing Record 42 of Set 11 | imbituba
# Processing Record 43 of Set 11 | cam ranh
# Processing Record 44 of Set 11 | monroe
# Processing Record 45 of Set 11 | north bend
# Processing Record 46 of Set 11 | hun
# Processing Record 47 of Set 11 | kotido
# Processing Record 48 of Set 11 | urumqi
# Processing Record 49 of Set 11 | mildura
# Processing Record 50 of Set 11 | townsville
# Processing Record 1 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 12 | morgan city
# Processing Record 3 of Set 12 | nioro
# Processing Record 4 of Set 12 | torrijos
# Processing Record 5 of Set 12 | shigony
# Processing Record 6 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | padang
# Processing Record 8 of Set 12 | chok chai
# Processing Record 9 of Set 12 | dhuburi
# Processing Record 10 of Set 12 | nieves
# Processing Record 11 of Set 12 | bilibino
# Processing Record 12 of Set 12 | veracruz
# Processing Record 13 of Set 12 | baghdad
# Processing Record 14 of Set 12 | payakumbuh
# Processing Record 15 of Set 12 | usinsk
# Processing Record 16 of Set 12 | sept-iles
# Processing Record 17 of Set 12 | mandiana
# Processing Record 18 of Set 12 | tirat karmel
# Processing Record 19 of Set 12 | kargasok
# Processing Record 20 of Set 12 | isangel
# Processing Record 21 of Set 12 | safranbolu
# Processing Record 22 of Set 12 | peniche
# Processing Record 23 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 12 | shetpe
# Processing Record 25 of Set 12 | san carlos del zulia
# Processing Record 26 of Set 12 | kindu
# Processing Record 27 of Set 12 | san jose de sisa
# Processing Record 28 of Set 12 | ruian
# City not found. Skipping...
# Processing Record 29 of Set 12 | bathsheba
# Processing Record 30 of Set 12 | kandrian
# Processing Record 31 of Set 12 | fukue
# Processing Record 32 of Set 12 | riyadh
# Processing Record 33 of Set 12 | ploemeur
# Processing Record 34 of Set 12 | khandbari
# Processing Record 35 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 12 | huarmey
# Processing Record 37 of Set 12 | muros
# Processing Record 38 of Set 12 | cap-aux-meules
# Processing Record 39 of Set 12 | cap malheureux
# Processing Record 40 of Set 12 | modasa
# Processing Record 41 of Set 12 | dongsheng
# Processing Record 42 of Set 12 | adana
# Processing Record 43 of Set 12 | anloga
# Processing Record 44 of Set 12 | komsomolskiy
# Processing Record 45 of Set 12 | fernie
# Processing Record 46 of Set 12 | rawlins
# Processing Record 47 of Set 12 | sao gabriel da cachoeira
# Processing Record 48 of Set 12 | kirkwall
# Processing Record 49 of Set 12 | yumen
# Processing Record 50 of Set 12 | beloha
# Processing Record 1 of Set 13 | tucurui
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | panama city
# Processing Record 4 of Set 13 | esso
# Processing Record 5 of Set 13 | fort saint james
# Processing Record 6 of Set 13 | mutsu
# Processing Record 7 of Set 13 | ouallam
# Processing Record 8 of Set 13 | lakefield
# Processing Record 9 of Set 13 | hashtrud
# Processing Record 10 of Set 13 | providencia
# Processing Record 11 of Set 13 | navapur
# City not found. Skipping...
# Processing Record 12 of Set 13 | twentynine palms
# Processing Record 13 of Set 13 | outjo
# Processing Record 14 of Set 13 | muncar
# Processing Record 15 of Set 13 | kirensk
# Processing Record 16 of Set 13 | eureka
# Processing Record 17 of Set 13 | meiganga
# Processing Record 18 of Set 13 | makakilo city
# Processing Record 19 of Set 13 | conceicao do araguaia
# Processing Record 20 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 13 | yako
# Processing Record 22 of Set 13 | nador
# Processing Record 23 of Set 13 | heihe
# Processing Record 24 of Set 13 | wakkanai
# Processing Record 25 of Set 13 | omsukchan
# Processing Record 26 of Set 13 | stornoway
# Processing Record 27 of Set 13 | kamaishi
# Processing Record 28 of Set 13 | general pico
# Processing Record 29 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 30 of Set 13 | leshukonskoye
# Processing Record 31 of Set 13 | valdemarpils
# Processing Record 32 of Set 13 | san jose
# Processing Record 33 of Set 13 | santa maria
# Processing Record 34 of Set 13 | coos bay
# Processing Record 35 of Set 13 | aswan
# Processing Record 36 of Set 13 | carballo
# Processing Record 37 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 13 | westport
# Processing Record 39 of Set 13 | elk city
# Processing Record 40 of Set 13 | katherine
# Processing Record 41 of Set 13 | ondjiva
# Processing Record 42 of Set 13 | venado tuerto
# Processing Record 43 of Set 13 | roebourne
# Processing Record 44 of Set 13 | vostok
# Processing Record 45 of Set 13 | mortka
# Processing Record 46 of Set 13 | upington
# Processing Record 47 of Set 13 | imatra
# Processing Record 48 of Set 13 | ternate
# Processing Record 49 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 50 of Set 13 | chengde
# Processing Record 1 of Set 14 | sindor
# Processing Record 2 of Set 14 | salinas
# Processing Record 3 of Set 14 | maniitsoq
# Processing Record 4 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 14 | dumas
# Processing Record 6 of Set 14 | dhangadhi
# Processing Record 7 of Set 14 | bridlington
# Processing Record 8 of Set 14 | hobyo
# Processing Record 9 of Set 14 | meulaboh
# Processing Record 10 of Set 14 | lac du bonnet
# Processing Record 11 of Set 14 | pangkalanbuun
# Processing Record 12 of Set 14 | kapoeta
# Processing Record 13 of Set 14 | phalodi
# Processing Record 14 of Set 14 | muravlenko
# Processing Record 15 of Set 14 | vangaindrano
# Processing Record 16 of Set 14 | nichinan
# Processing Record 17 of Set 14 | mpanda
# Processing Record 18 of Set 14 | sishui
# Processing Record 19 of Set 14 | the pas
# Processing Record 20 of Set 14 | murgab
# Processing Record 21 of Set 14 | vilhena
# Processing Record 22 of Set 14 | del rio
# Processing Record 23 of Set 14 | pleasanton
# Processing Record 24 of Set 14 | bintulu
# Processing Record 25 of Set 14 | port augusta
# Processing Record 26 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 27 of Set 14 | kemi
# Processing Record 28 of Set 14 | caxito
# Processing Record 29 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 14 | acarau
# Processing Record 31 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 14 | kerema
# Processing Record 33 of Set 14 | pingliang
# Processing Record 34 of Set 14 | manokwari
# Processing Record 35 of Set 14 | narasannapeta
# Processing Record 36 of Set 14 | palmeirais
# Processing Record 37 of Set 14 | mariental
# Processing Record 38 of Set 14 | waingapu
# Processing Record 39 of Set 14 | aksu
# Processing Record 40 of Set 14 | bay roberts
# Processing Record 41 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 14 | onufriyivka
# Processing Record 43 of Set 14 | kieta
# Processing Record 44 of Set 14 | rocky mountain house
# Processing Record 45 of Set 14 | qui nhon
# Processing Record 46 of Set 14 | xique-xique
# Processing Record 47 of Set 14 | bilma
# Processing Record 48 of Set 14 | port keats
# Processing Record 49 of Set 14 | puerto del rosario
# Processing Record 50 of Set 14 | malindi
# Processing Record 1 of Set 15 | launceston
# Processing Record 2 of Set 15 | pahrump
# Processing Record 3 of Set 15 | port-gentil
# Processing Record 4 of Set 15 | cedar falls
# Processing Record 5 of Set 15 | vestmanna
# Processing Record 6 of Set 15 | plettenberg bay
# Processing Record 7 of Set 15 | covington
# Processing Record 8 of Set 15 | burnie
# Processing Record 9 of Set 15 | chinteni
# Processing Record 10 of Set 15 | vao
# Processing Record 11 of Set 15 | karratha
# Processing Record 12 of Set 15 | veraval
# Processing Record 13 of Set 15 | derzhavinsk
# Processing Record 14 of Set 15 | itarema
# Processing Record 15 of Set 15 | beresti-sat
# Processing Record 16 of Set 15 | monrovia
# Processing Record 17 of Set 15 | voyvozh
# Processing Record 18 of Set 15 | gobabis
# Processing Record 19 of Set 15 | mayo
# Processing Record 20 of Set 15 | cancun
# Processing Record 21 of Set 15 | gorontalo
# Processing Record 22 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 15 | rebrikha
# Processing Record 24 of Set 15 | perpignan
# Processing Record 25 of Set 15 | fomboni
# Processing Record 26 of Set 15 | ponta delgada
# Processing Record 27 of Set 15 | pecanha
# Processing Record 28 of Set 15 | kebemer
# City not found. Skipping...
# Processing Record 29 of Set 15 | chenzhou
# Processing Record 30 of Set 15 | tual
# Processing Record 31 of Set 15 | baruun-urt
# Processing Record 32 of Set 15 | pizarro
# Processing Record 33 of Set 15 | baiyin
# Processing Record 34 of Set 15 | senanga
# Processing Record 35 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 15 | sarankhola
# Processing Record 37 of Set 15 | lander
# Processing Record 38 of Set 15 | canico
# Processing Record 39 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 15 | terrace
# Processing Record 41 of Set 15 | chapada dos guimaraes
# Processing Record 42 of Set 15 | pombas
# Processing Record 43 of Set 15 | oriximina
# Processing Record 44 of Set 15 | mecca
# Processing Record 45 of Set 15 | sur
# Processing Record 46 of Set 15 | chimbote
# Processing Record 47 of Set 15 | bardiyah
# Processing Record 48 of Set 15 | gawler
# Processing Record 49 of Set 15 | kita
# Processing Record 50 of Set 15 | sherbrooke
# Processing Record 1 of Set 16 | cadereyta
# Processing Record 2 of Set 16 | oranjestad
# Processing Record 3 of Set 16 | ostrovskoye
# Processing Record 4 of Set 16 | northam
# Processing Record 5 of Set 16 | acapulco
# Processing Record 6 of Set 16 | manaskent
# Processing Record 7 of Set 16 | nsoko
# Processing Record 8 of Set 16 | homorod-de jos
# City not found. Skipping...
# Processing Record 9 of Set 16 | birao
# Processing Record 10 of Set 16 | itaituba
# Processing Record 11 of Set 16 | samarai
# Processing Record 12 of Set 16 | trincomalee
# Processing Record 13 of Set 16 | jaque
# Processing Record 14 of Set 16 | russell
# Processing Record 15 of Set 16 | birjand
# Processing Record 16 of Set 16 | guerrero negro
# Processing Record 17 of Set 16 | marzuq
# Processing Record 18 of Set 16 | el vendrell
# Processing Record 19 of Set 16 | kasongo
# Processing Record 20 of Set 16 | hargeysa
# Processing Record 21 of Set 16 | yulara
# Processing Record 22 of Set 16 | novoorsk
# Processing Record 23 of Set 16 | batagay-alyta
# Processing Record 24 of Set 16 | kempele
# Processing Record 25 of Set 16 | pakhtakoron
# Processing Record 26 of Set 16 | yantongshan
# Processing Record 27 of Set 16 | pontes e lacerda
# Processing Record 28 of Set 16 | la ronge
# Processing Record 29 of Set 16 | horsham
# Processing Record 30 of Set 16 | petrov val
# Processing Record 31 of Set 16 | loikaw
# Processing Record 32 of Set 16 | orocue
# Processing Record 33 of Set 16 | cayenne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 718

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Lata      PT  40.1629   -8.3327     41.07        87          37
# 1     Kirakira      SB -10.4544  161.9205     84.02        73          94
# 2     Khatanga      RU  71.9667  102.5000    -31.22       100          35
# 3    Kilindoni      TZ  -7.9139   39.6668     79.95        77          97
# 4   Turukhansk      RU  65.8167   87.9833    -16.46        79         100
# 5      College      US  64.8569 -147.8028     -8.93        76          40
# 6       Faanui      PF -16.4833 -151.7500     80.82        72          18
# 7    Mahebourg      MU -20.4081   57.7000     78.26        94          75
# 8       Avarua      CK -21.2078 -159.7750     78.85        89          75
# 9  East London      ZA -33.0153   27.9116     77.70        83          70
#
#    Wind Speed Current Description
# 0        1.07    scattered clouds
# 1       13.60          light rain
# 2        6.89    scattered clouds
# 3        7.09     overcast clouds
# 4        7.85     overcast clouds
# 5        0.00                haze
# 6       14.41          light rain
# 7       20.71       moderate rain
# 8        6.91          light rain
# 9       16.40       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Display the data types of each column by using the dtypes Pandas function
results =city_data_df.dtypes
print(results)
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
